# %%
name ="aparna"

# %%
name
# Out:
# 'aparna'

# %%
name.upper()
# Out:
# 'APARNA'

# %%
name.endswith("na")
# Out:
# True

# %%
name.lower()
# Out:
# 'aparna'

# %%
name.count("a")
# Out:
# 3

# %%
len(name)
# Out:
# 6

# %%
name[0:4]
# Out:
# 'apar'

# %%
name[0:6]
# Out:
# 'aparna'
