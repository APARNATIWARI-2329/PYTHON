# %%
a=5

# %%
b=32

# %%
a+b
# Out:
# 37

# %%
name = "aparna"

# %%
print("hello world")
# Out:
# hello world

# %%
# this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(name)
# Out:
# str

# %%
a="4566"

# %%
b="3211"

# %%
print(a+b)
# Out:
# 45663211

# %%
int(a)+int(b) #typecasting
# Out:
# 7777
